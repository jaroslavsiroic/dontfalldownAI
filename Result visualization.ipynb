# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def draw_scatter(path, save_name):
    df = pd.read_csv(path)
    df.set_index('Unnamed: 0', inplace=True)
    plot = df.plot.scatter('generation', 'fitness')
    plot.figure.savefig(save_name)

# %%
df = pd.read_csv('./saved/2018_06_17__22_35_02/results.csv')
df.set_index('Unnamed: 0', inplace=True)
df.head()
# Out:
#             generation  fitness
# Unnamed: 0
# 0                    1      248
# 1                    1        0
# 2                    1        0
# 3                    1        0
# 4                    1        0

# %%
scatter = df.plot.scatter('generation', 'fitness')

# %%
scatter.figure.savefig('foo.png')

# %%
draw_scatter('./saved/2018_06_17__22_35_02/results.csv', 'test.png')
